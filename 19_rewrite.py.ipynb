# %% [markdown]
# Problem 18 from the advent of code calendar 2022.
#
#
# January 3, 2023

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

np.set_printoptions(linewidth=250)

# %%
#Load in the data
with open("19.txt") as f:
    contents = f.readlines()
    
    
def process_line(l):
    """
    Returns the blueprint id and a dictionary where the values are arrays of cost to build the key
    ordered by 
    
        [ore_cost,clay_cost,obsidian_cost,geode_cost]
    """
    s = l.split()
    bid = int(s[1].rstrip(':'))
    ore = int(s[6])
    clay = int(s[12])
    obsidian_ore = int(s[18])
    obsidian_clay = int(s[21])
    geode_ore = int(s[27])
    geode_obsidian = int(s[30])
    
    blueprint = {}
    blueprint['ore'] = np.array([ore,0,0,0])
    blueprint['clay'] = np.array([clay,0,0,0])
    blueprint['obsidian'] = np.array([obsidian_ore, obsidian_clay,0,0])
    blueprint['geode'] = np.array([geode_ore,0,geode_obsidian,0])
    
    return bid, blueprint


#Keeping track of the index of all of our different types of objects
TRANSLATION = {}
TRANSLATION['ore'] = 0
TRANSLATION['clay'] = 1
TRANSLATION['obsidian'] = 2
TRANSLATION['geode'] = 3

# %%
"""
Creating a test blueprint from the description to check the code below

Blueprint 1:
  Each ore robot costs 4 ore.
  Each clay robot costs 2 ore.
  Each obsidian robot costs 3 ore and 14 clay.
  Each geode robot costs 2 ore and 7 obsidian.


"""

test_dict = {}
test_dict['ore'] = np.array([4,0,0,0])
test_dict['clay'] = np.array([2,0,0,0])
test_dict['obsidian'] = np.array([3, 14,0,0])
test_dict['geode'] = np.array([2,0,7,0])

tid = "t1"

# %%
class Robots_and_resources():
    """
    Keeping the robots we have and the resource we have matched up.
    """
    
    def __init__(self, robot_list, resource_list):
        self.robots = robot_list
        self.resources = resource_list
    
    def __repr__(self):
        return 'Robots: {}   Resources: {}'.format(self.robots, self.resources)
    
    def flatten(self):
        return np.append(self.robots,self.resources)
    
    def compare(self,rr):
        """
        Given another robot rr, determine whether rr is better (same robots but more or less resource)
        """
        rval = 0
        if (self.flatten() - rr.flatten()).min() >= 0:
            rval = 1
        elif (self.flatten() - rr.flatten()).max() < 0:
            rval = -1
        return rval
    
    
class Blueprint():
    """
    Tracking traveling through a blueprint
    """
    
    def __init__(self, blueprint_id, blueprint_dict, starting_robots):
        self.id = blueprint_id
        self.blueprints = blueprint_dict
        self.minute_lists = [[starting_robots]] #This is a list where the index indicates the day and the list at that 
                             # index is of the different configurations of robot_and_resources available at that day.

            
    def __repr__(self):
        wstr = 'Blueprint id: {}\n'.format(self.id)
        wstr = wstr + 'Blueprints: {}\n'.format(self.blueprints)
        for i in range(len(self.minute_lists)):
            wstr = wstr + 'After minute {}: \n'.format(i)
            for l in self.minute_lists[i]:
                wstr = wstr + '\t' + str(l) + '\n'
        return wstr
            
    def elapsed_time(self):
        return len(self.minute_lists) - 1
    
    def extend_a_robot(self,robots):
        """
        Input:  
               robots      Robots_and_resources class 
               
        Output:
               List of Robots_and_resources classes that are possible after 1 minute given the blueprints
               
        """
        
        cur_robots = robots.robots.copy()
        cur_resources = robots.resources.copy()
        #Start by putting the case where we don't built any robots into the return list
        nlist = [Robots_and_resources(cur_robots,cur_resources + cur_robots)]
        #Next go through the blueprint and for each one see if it is possible to build that robot.  If it is 
        #possible then add the case where that robot is built to the list.
        for kind in self.blueprints:
            resource_cost = self.blueprints[kind]
            if (cur_resources - resource_cost).min() >= 0:
                #Now checking if we need more of this type of machine
                #print (cur_robots, TRANSLATION[kind])
                if cur_robots[TRANSLATION[kind]] < self.machine_bounds()[TRANSLATION[kind]]:
                 
                    new_resources = cur_resources - resource_cost + cur_robots
                    #Surprising amount of code to increase cur_robots in the right spot to new_robots
                    new_robots = cur_robots.copy()
                    new_robots[TRANSLATION[kind]] += 1
                    nlist.append(Robots_and_resources(new_robots,new_resources))
        return nlist            

    def machine_bounds(self):
        """
        Return how many machines of a given non-geode type are needed to be able to build any machine 
        the following day
        """
        bounds = pd.DataFrame(self.blueprints).max(axis = 1)
        bounds[3] = 100000 #cause we can't have too many geode machines
        return bounds
        
    
    def trim_list(self,tlist):
        """
        At a certain point the possibility list gets *way* too long.  So we need to trim it back.  We compare
        all cases where we have the same number of robots and only keep the ones that maximize the number of 
        resources. Note we are doing this on an external and not an internal list.  Just like the previous 
        function.
        """
        #weights = np.array([1000,100,10,1,0,0,0,0])
        rlist = [x.flatten() for x in tlist]
        #print("Original length: {}".format(len(rlist)))
        rlist = np.unique(np.array(rlist),axis = 0)
        rlist = np.unique(rlist,axis = 0)
        #print("Deduped length: {}".format(len(rlist)))
        #rlist.sort(key = lambda x: (x.flatten()*weights).sum())
        #print(np.array(rlist))
        bustle = rlist
        bust = np.append(bustle[np.where(np.diff(bustle,axis = 0).min(axis = 1) < 0)],[bustle[-1,:]],axis = 0)
        #print("Post trim length: {}".format(bust.shape))
        #print(bust)
        
        
        rlist = [Robots_and_resources(x[:4],x[4:]) for x in bust]
        
        
        
        
        """
        for i in range(len(tlist)):
            rr = tlist[i]
            keep = True
            for j in range(i+1,len(tlist)):
                if tlist[j].compare(rr) >0:
                    keep = False
            if keep:
                rlist.append(rr)
                
        """
        return rlist
    
    
    
    def add_a_minute(self):
        cur_list = self.minute_lists[-1]
        next_list = []
        for rr in cur_list:
            next_list.extend(self.extend_a_robot(rr))
        next_list = self.trim_list(next_list)
        if len(next_list) > 10:
            next_list = self.trim_list(next_list)
        if len(next_list) > 100:
            next_list = self.trim_list(next_list)
        if len(next_list) > 1000:
            next_list = self.trim_list(next_list)
            next_list = self.trim_list(next_list)
        self.minute_lists.append(next_list)
        return None
         
    
    def geodes(self,minute):
        """
        Returns the max number of geodes that could be found in that minute
        """
        assert(minute <= self.elapsed_time())
        tlist = [x.resources[3] for x in self.minute_lists[minute]]
        return max(tlist)
    
#Note that all blueprints start with 1 ore robot and nothing else        
STARTING_STATE = Robots_and_resources(np.array([1,0,0,0]),np.array([0,0,0,0]))

# %%
STARTING_STATE
# Out:
# Robots: [1 0 0 0]   Resources: [0 0 0 0]

# %%
entry = 0
for line in range(30):
    b = Blueprint(*process_line(contents[line]), STARTING_STATE)
    print("STARTING on blueprint {}".format(b.id))
    
    for i in range(24):
        b.add_a_minute()
        print('Branches: {}\t Elapsed time: {} \t Geodes found: {}'.format(len(b.minute_lists[-1]),b.elapsed_time(),b.geodes(b.elapsed_time())) )   
    
    entry = entry + b.id*b.geodes(24)

print("AND THE ENTRY SHOULD BE (FINGERS CROSSED) {}".format(entry))
# Out:
# STARTING on blueprint 1
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 4	 Elapsed time: 5 	 Geodes found: 0
# Branches: 6	 Elapsed time: 6 	 Geodes found: 0
# Branches: 10	 Elapsed time: 7 	 Geodes found: 0
# Branches: 14	 Elapsed time: 8 	 Geodes found: 0
# Branches: 19	 Elapsed time: 9 	 Geodes found: 0
# Branches: 23	 Elapsed time: 10 	 Geodes found: 0
# Branches: 28	 Elapsed time: 11 	 Geodes found: 0
# Branches: 31	 Elapsed time: 12 	 Geodes found: 0
# Branches: 34	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 49	 Elapsed time: 15 	 Geodes found: 0
# Branches: 64	 Elapsed time: 16 	 Geodes found: 0
# Branches: 86	 Elapsed time: 17 	 Geodes found: 0
# Branches: 104	 Elapsed time: 18 	 Geodes found: 0
# Branches: 145	 Elapsed time: 19 	 Geodes found: 0
# Branches: 211	 Elapsed time: 20 	 Geodes found: 0
# Branches: 327	 Elapsed time: 21 	 Geodes found: 0
# Branches: 471	 Elapsed time: 22 	 Geodes found: 0
# Branches: 783	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1235	 Elapsed time: 24 	 Geodes found: 1
# STARTING on blueprint 2
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 3	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 5	 Elapsed time: 6 	 Geodes found: 0
# Branches: 7	 Elapsed time: 7 	 Geodes found: 0
# Branches: 10	 Elapsed time: 8 	 Geodes found: 0
# Branches: 16	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 25	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 36	 Elapsed time: 13 	 Geodes found: 0
# Branches: 42	 Elapsed time: 14 	 Geodes found: 0
# Branches: 62	 Elapsed time: 15 	 Geodes found: 0
# Branches: 84	 Elapsed time: 16 	 Geodes found: 0
# Branches: 93	 Elapsed time: 17 	 Geodes found: 0
# Branches: 134	 Elapsed time: 18 	 Geodes found: 0
# Branches: 185	 Elapsed time: 19 	 Geodes found: 0
# Branches: 265	 Elapsed time: 20 	 Geodes found: 0
# Branches: 378	 Elapsed time: 21 	 Geodes found: 0
# Branches: 556	 Elapsed time: 22 	 Geodes found: 0
# Branches: 812	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1138	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 3
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 3	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 5	 Elapsed time: 6 	 Geodes found: 0
# Branches: 7	 Elapsed time: 7 	 Geodes found: 0
# Branches: 10	 Elapsed time: 8 	 Geodes found: 0
# Branches: 16	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 25	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 36	 Elapsed time: 13 	 Geodes found: 0
# Branches: 52	 Elapsed time: 14 	 Geodes found: 0
# Branches: 74	 Elapsed time: 15 	 Geodes found: 0
# Branches: 93	 Elapsed time: 16 	 Geodes found: 0
# Branches: 125	 Elapsed time: 17 	 Geodes found: 0
# Branches: 178	 Elapsed time: 18 	 Geodes found: 0
# Branches: 256	 Elapsed time: 19 	 Geodes found: 0
# Branches: 379	 Elapsed time: 20 	 Geodes found: 0
# Branches: 617	 Elapsed time: 21 	 Geodes found: 0
# Branches: 999	 Elapsed time: 22 	 Geodes found: 1
# Branches: 1769	 Elapsed time: 23 	 Geodes found: 2
# Branches: 3423	 Elapsed time: 24 	 Geodes found: 3
# STARTING on blueprint 4
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 4	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 9	 Elapsed time: 8 	 Geodes found: 0
# Branches: 14	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 24	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 38	 Elapsed time: 13 	 Geodes found: 0
# Branches: 44	 Elapsed time: 14 	 Geodes found: 0
# Branches: 62	 Elapsed time: 15 	 Geodes found: 0
# Branches: 88	 Elapsed time: 16 	 Geodes found: 0
# Branches: 108	 Elapsed time: 17 	 Geodes found: 0
# Branches: 156	 Elapsed time: 18 	 Geodes found: 0
# Branches: 224	 Elapsed time: 19 	 Geodes found: 0
# Branches: 341	 Elapsed time: 20 	 Geodes found: 0
# Branches: 527	 Elapsed time: 21 	 Geodes found: 0
# Branches: 810	 Elapsed time: 22 	 Geodes found: 0
# Branches: 1197	 Elapsed time: 23 	 Geodes found: 0
# Branches: 2027	 Elapsed time: 24 	 Geodes found: 1
# STARTING on blueprint 5
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 4	 Elapsed time: 5 	 Geodes found: 0
# Branches: 6	 Elapsed time: 6 	 Geodes found: 0
# Branches: 10	 Elapsed time: 7 	 Geodes found: 0
# Branches: 14	 Elapsed time: 8 	 Geodes found: 0
# Branches: 19	 Elapsed time: 9 	 Geodes found: 0
# Branches: 23	 Elapsed time: 10 	 Geodes found: 0
# Branches: 28	 Elapsed time: 11 	 Geodes found: 0
# Branches: 31	 Elapsed time: 12 	 Geodes found: 0
# Branches: 34	 Elapsed time: 13 	 Geodes found: 0
# Branches: 43	 Elapsed time: 14 	 Geodes found: 0
# Branches: 54	 Elapsed time: 15 	 Geodes found: 0
# Branches: 77	 Elapsed time: 16 	 Geodes found: 0
# Branches: 102	 Elapsed time: 17 	 Geodes found: 0
# Branches: 142	 Elapsed time: 18 	 Geodes found: 0
# Branches: 197	 Elapsed time: 19 	 Geodes found: 0
# Branches: 313	 Elapsed time: 20 	 Geodes found: 0
# Branches: 497	 Elapsed time: 21 	 Geodes found: 0
# Branches: 801	 Elapsed time: 22 	 Geodes found: 0
# Branches: 1299	 Elapsed time: 23 	 Geodes found: 1
# Branches: 2297	 Elapsed time: 24 	 Geodes found: 2
# STARTING on blueprint 6
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 4	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 9	 Elapsed time: 8 	 Geodes found: 0
# Branches: 14	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 24	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 38	 Elapsed time: 13 	 Geodes found: 0
# Branches: 44	 Elapsed time: 14 	 Geodes found: 0
# Branches: 68	 Elapsed time: 15 	 Geodes found: 0
# Branches: 93	 Elapsed time: 16 	 Geodes found: 0
# Branches: 115	 Elapsed time: 17 	 Geodes found: 0
# Branches: 160	 Elapsed time: 18 	 Geodes found: 0
# Branches: 239	 Elapsed time: 19 	 Geodes found: 0
# Branches: 366	 Elapsed time: 20 	 Geodes found: 0
# Branches: 586	 Elapsed time: 21 	 Geodes found: 0
# Branches: 929	 Elapsed time: 22 	 Geodes found: 0
# Branches: 1402	 Elapsed time: 23 	 Geodes found: 0
# Branches: 2333	 Elapsed time: 24 	 Geodes found: 1
# STARTING on blueprint 7
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 4	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 9	 Elapsed time: 8 	 Geodes found: 0
# Branches: 14	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 24	 Elapsed time: 11 	 Geodes found: 0
# Branches: 37	 Elapsed time: 12 	 Geodes found: 0
# Branches: 62	 Elapsed time: 13 	 Geodes found: 0
# Branches: 85	 Elapsed time: 14 	 Geodes found: 0
# Branches: 126	 Elapsed time: 15 	 Geodes found: 0
# Branches: 194	 Elapsed time: 16 	 Geodes found: 0
# Branches: 318	 Elapsed time: 17 	 Geodes found: 0
# Branches: 506	 Elapsed time: 18 	 Geodes found: 0
# Branches: 792	 Elapsed time: 19 	 Geodes found: 0
# Branches: 1225	 Elapsed time: 20 	 Geodes found: 0
# Branches: 1855	 Elapsed time: 21 	 Geodes found: 0
# Branches: 2856	 Elapsed time: 22 	 Geodes found: 1
# Branches: 4711	 Elapsed time: 23 	 Geodes found: 2
# Branches: 7888	 Elapsed time: 24 	 Geodes found: 3
# STARTING on blueprint 8
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 4	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 9	 Elapsed time: 8 	 Geodes found: 0
# Branches: 14	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 26	 Elapsed time: 11 	 Geodes found: 0
# Branches: 41	 Elapsed time: 12 	 Geodes found: 0
# Branches: 71	 Elapsed time: 13 	 Geodes found: 0
# Branches: 101	 Elapsed time: 14 	 Geodes found: 0
# Branches: 146	 Elapsed time: 15 	 Geodes found: 0
# Branches: 234	 Elapsed time: 16 	 Geodes found: 0
# Branches: 374	 Elapsed time: 17 	 Geodes found: 0
# Branches: 604	 Elapsed time: 18 	 Geodes found: 0
# Branches: 1051	 Elapsed time: 19 	 Geodes found: 1
# Branches: 1914	 Elapsed time: 20 	 Geodes found: 2
# Branches: 3712	 Elapsed time: 21 	 Geodes found: 4
# Branches: 7058	 Elapsed time: 22 	 Geodes found: 6
# Branches: 13286	 Elapsed time: 23 	 Geodes found: 9
# Branches: 24784	 Elapsed time: 24 	 Geodes found: 13
# STARTING on blueprint 9
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 4	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 9	 Elapsed time: 8 	 Geodes found: 0
# Branches: 14	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 24	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 38	 Elapsed time: 13 	 Geodes found: 0
# Branches: 44	 Elapsed time: 14 	 Geodes found: 0
# Branches: 48	 Elapsed time: 15 	 Geodes found: 0
# Branches: 68	 Elapsed time: 16 	 Geodes found: 0
# Branches: 91	 Elapsed time: 17 	 Geodes found: 0
# Branches: 108	 Elapsed time: 18 	 Geodes found: 0
# Branches: 148	 Elapsed time: 19 	 Geodes found: 0
# Branches: 201	 Elapsed time: 20 	 Geodes found: 0
# Branches: 288	 Elapsed time: 21 	 Geodes found: 0
# Branches: 410	 Elapsed time: 22 	 Geodes found: 0
# Branches: 715	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1196	 Elapsed time: 24 	 Geodes found: 1
# STARTING on blueprint 10
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 3	 Elapsed time: 4 	 Geodes found: 0
# Branches: 5	 Elapsed time: 5 	 Geodes found: 0
# Branches: 8	 Elapsed time: 6 	 Geodes found: 0
# Branches: 11	 Elapsed time: 7 	 Geodes found: 0
# Branches: 15	 Elapsed time: 8 	 Geodes found: 0
# Branches: 18	 Elapsed time: 9 	 Geodes found: 0
# Branches: 21	 Elapsed time: 10 	 Geodes found: 0
# Branches: 25	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 42	 Elapsed time: 13 	 Geodes found: 0
# Branches: 58	 Elapsed time: 14 	 Geodes found: 0
# Branches: 82	 Elapsed time: 15 	 Geodes found: 0
# Branches: 107	 Elapsed time: 16 	 Geodes found: 0
# Branches: 149	 Elapsed time: 17 	 Geodes found: 0
# Branches: 228	 Elapsed time: 18 	 Geodes found: 0
# Branches: 388	 Elapsed time: 19 	 Geodes found: 1
# Branches: 703	 Elapsed time: 20 	 Geodes found: 2
# Branches: 1251	 Elapsed time: 21 	 Geodes found: 3
# Branches: 2365	 Elapsed time: 22 	 Geodes found: 5
# Branches: 4742	 Elapsed time: 23 	 Geodes found: 7
# Branches: 9560	 Elapsed time: 24 	 Geodes found: 10
# STARTING on blueprint 11
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 4	 Elapsed time: 5 	 Geodes found: 0
# Branches: 6	 Elapsed time: 6 	 Geodes found: 0
# Branches: 10	 Elapsed time: 7 	 Geodes found: 0
# Branches: 14	 Elapsed time: 8 	 Geodes found: 0
# Branches: 19	 Elapsed time: 9 	 Geodes found: 0
# Branches: 23	 Elapsed time: 10 	 Geodes found: 0
# Branches: 28	 Elapsed time: 11 	 Geodes found: 0
# Branches: 31	 Elapsed time: 12 	 Geodes found: 0
# Branches: 34	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 50	 Elapsed time: 15 	 Geodes found: 0
# Branches: 64	 Elapsed time: 16 	 Geodes found: 0
# Branches: 87	 Elapsed time: 17 	 Geodes found: 0
# Branches: 109	 Elapsed time: 18 	 Geodes found: 0
# Branches: 152	 Elapsed time: 19 	 Geodes found: 0
# Branches: 211	 Elapsed time: 20 	 Geodes found: 0
# Branches: 313	 Elapsed time: 21 	 Geodes found: 0
# Branches: 477	 Elapsed time: 22 	 Geodes found: 0
# Branches: 780	 Elapsed time: 23 	 Geodes found: 1
# Branches: 1247	 Elapsed time: 24 	 Geodes found: 2
# STARTING on blueprint 12
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 4	 Elapsed time: 5 	 Geodes found: 0
# Branches: 6	 Elapsed time: 6 	 Geodes found: 0
# Branches: 10	 Elapsed time: 7 	 Geodes found: 0
# Branches: 14	 Elapsed time: 8 	 Geodes found: 0
# Branches: 19	 Elapsed time: 9 	 Geodes found: 0
# Branches: 23	 Elapsed time: 10 	 Geodes found: 0
# Branches: 28	 Elapsed time: 11 	 Geodes found: 0
# Branches: 31	 Elapsed time: 12 	 Geodes found: 0
# Branches: 34	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 49	 Elapsed time: 15 	 Geodes found: 0
# Branches: 64	 Elapsed time: 16 	 Geodes found: 0
# Branches: 86	 Elapsed time: 17 	 Geodes found: 0
# Branches: 104	 Elapsed time: 18 	 Geodes found: 0
# Branches: 145	 Elapsed time: 19 	 Geodes found: 0
# Branches: 211	 Elapsed time: 20 	 Geodes found: 0
# Branches: 327	 Elapsed time: 21 	 Geodes found: 0
# Branches: 471	 Elapsed time: 22 	 Geodes found: 0
# Branches: 751	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1132	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 13
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 1	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 3	 Elapsed time: 7 	 Geodes found: 0
# Branches: 5	 Elapsed time: 8 	 Geodes found: 0
# Branches: 7	 Elapsed time: 9 	 Geodes found: 0
# Branches: 11	 Elapsed time: 10 	 Geodes found: 0
# Branches: 14	 Elapsed time: 11 	 Geodes found: 0
# Branches: 24	 Elapsed time: 12 	 Geodes found: 0
# Branches: 29	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 45	 Elapsed time: 15 	 Geodes found: 0
# Branches: 61	 Elapsed time: 16 	 Geodes found: 0
# Branches: 88	 Elapsed time: 17 	 Geodes found: 0
# Branches: 119	 Elapsed time: 18 	 Geodes found: 0
# Branches: 146	 Elapsed time: 19 	 Geodes found: 0
# Branches: 206	 Elapsed time: 20 	 Geodes found: 0
# Branches: 299	 Elapsed time: 21 	 Geodes found: 0
# Branches: 470	 Elapsed time: 22 	 Geodes found: 0
# Branches: 741	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1137	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 14
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 4	 Elapsed time: 5 	 Geodes found: 0
# Branches: 6	 Elapsed time: 6 	 Geodes found: 0
# Branches: 10	 Elapsed time: 7 	 Geodes found: 0
# Branches: 14	 Elapsed time: 8 	 Geodes found: 0
# Branches: 19	 Elapsed time: 9 	 Geodes found: 0
# Branches: 23	 Elapsed time: 10 	 Geodes found: 0
# Branches: 28	 Elapsed time: 11 	 Geodes found: 0
# Branches: 31	 Elapsed time: 12 	 Geodes found: 0
# Branches: 34	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 50	 Elapsed time: 15 	 Geodes found: 0
# Branches: 64	 Elapsed time: 16 	 Geodes found: 0
# Branches: 86	 Elapsed time: 17 	 Geodes found: 0
# Branches: 106	 Elapsed time: 18 	 Geodes found: 0
# Branches: 148	 Elapsed time: 19 	 Geodes found: 0
# Branches: 205	 Elapsed time: 20 	 Geodes found: 0
# Branches: 303	 Elapsed time: 21 	 Geodes found: 0
# Branches: 437	 Elapsed time: 22 	 Geodes found: 0
# Branches: 689	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1000	 Elapsed time: 24 	 Geodes found: 1
# STARTING on blueprint 15
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 1	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 3	 Elapsed time: 7 	 Geodes found: 0
# Branches: 5	 Elapsed time: 8 	 Geodes found: 0
# Branches: 7	 Elapsed time: 9 	 Geodes found: 0
# Branches: 11	 Elapsed time: 10 	 Geodes found: 0
# Branches: 14	 Elapsed time: 11 	 Geodes found: 0
# Branches: 24	 Elapsed time: 12 	 Geodes found: 0
# Branches: 29	 Elapsed time: 13 	 Geodes found: 0
# Branches: 40	 Elapsed time: 14 	 Geodes found: 0
# Branches: 52	 Elapsed time: 15 	 Geodes found: 0
# Branches: 80	 Elapsed time: 16 	 Geodes found: 0
# Branches: 119	 Elapsed time: 17 	 Geodes found: 0
# Branches: 152	 Elapsed time: 18 	 Geodes found: 0
# Branches: 235	 Elapsed time: 19 	 Geodes found: 0
# Branches: 352	 Elapsed time: 20 	 Geodes found: 0
# Branches: 570	 Elapsed time: 21 	 Geodes found: 0
# Branches: 987	 Elapsed time: 22 	 Geodes found: 0
# Branches: 1825	 Elapsed time: 23 	 Geodes found: 1
# Branches: 3565	 Elapsed time: 24 	 Geodes found: 2
# STARTING on blueprint 16
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 7	 Elapsed time: 8 	 Geodes found: 0
# Branches: 10	 Elapsed time: 9 	 Geodes found: 0
# Branches: 15	 Elapsed time: 10 	 Geodes found: 0
# Branches: 23	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 43	 Elapsed time: 13 	 Geodes found: 0
# Branches: 56	 Elapsed time: 14 	 Geodes found: 0
# Branches: 72	 Elapsed time: 15 	 Geodes found: 0
# Branches: 100	 Elapsed time: 16 	 Geodes found: 0
# Branches: 148	 Elapsed time: 17 	 Geodes found: 0
# Branches: 213	 Elapsed time: 18 	 Geodes found: 0
# Branches: 309	 Elapsed time: 19 	 Geodes found: 0
# Branches: 506	 Elapsed time: 20 	 Geodes found: 0
# Branches: 789	 Elapsed time: 21 	 Geodes found: 0
# Branches: 1282	 Elapsed time: 22 	 Geodes found: 0
# Branches: 2058	 Elapsed time: 23 	 Geodes found: 0
# Branches: 3305	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 17
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 4	 Elapsed time: 5 	 Geodes found: 0
# Branches: 6	 Elapsed time: 6 	 Geodes found: 0
# Branches: 10	 Elapsed time: 7 	 Geodes found: 0
# Branches: 14	 Elapsed time: 8 	 Geodes found: 0
# Branches: 19	 Elapsed time: 9 	 Geodes found: 0
# Branches: 23	 Elapsed time: 10 	 Geodes found: 0
# Branches: 28	 Elapsed time: 11 	 Geodes found: 0
# Branches: 31	 Elapsed time: 12 	 Geodes found: 0
# Branches: 34	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 50	 Elapsed time: 15 	 Geodes found: 0
# Branches: 64	 Elapsed time: 16 	 Geodes found: 0
# Branches: 86	 Elapsed time: 17 	 Geodes found: 0
# Branches: 106	 Elapsed time: 18 	 Geodes found: 0
# Branches: 154	 Elapsed time: 19 	 Geodes found: 0
# Branches: 217	 Elapsed time: 20 	 Geodes found: 0
# Branches: 321	 Elapsed time: 21 	 Geodes found: 0
# Branches: 466	 Elapsed time: 22 	 Geodes found: 0
# Branches: 751	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1082	 Elapsed time: 24 	 Geodes found: 1
# STARTING on blueprint 18
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 1	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 3	 Elapsed time: 7 	 Geodes found: 0
# Branches: 5	 Elapsed time: 8 	 Geodes found: 0
# Branches: 7	 Elapsed time: 9 	 Geodes found: 0
# Branches: 11	 Elapsed time: 10 	 Geodes found: 0
# Branches: 14	 Elapsed time: 11 	 Geodes found: 0
# Branches: 24	 Elapsed time: 12 	 Geodes found: 0
# Branches: 29	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 45	 Elapsed time: 15 	 Geodes found: 0
# Branches: 62	 Elapsed time: 16 	 Geodes found: 0
# Branches: 90	 Elapsed time: 17 	 Geodes found: 0
# Branches: 123	 Elapsed time: 18 	 Geodes found: 0
# Branches: 154	 Elapsed time: 19 	 Geodes found: 0
# Branches: 245	 Elapsed time: 20 	 Geodes found: 0
# Branches: 341	 Elapsed time: 21 	 Geodes found: 0
# Branches: 536	 Elapsed time: 22 	 Geodes found: 0
# Branches: 807	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1264	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 19
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 7	 Elapsed time: 8 	 Geodes found: 0
# Branches: 10	 Elapsed time: 9 	 Geodes found: 0
# Branches: 15	 Elapsed time: 10 	 Geodes found: 0
# Branches: 23	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 43	 Elapsed time: 13 	 Geodes found: 0
# Branches: 59	 Elapsed time: 14 	 Geodes found: 0
# Branches: 83	 Elapsed time: 15 	 Geodes found: 0
# Branches: 121	 Elapsed time: 16 	 Geodes found: 0
# Branches: 184	 Elapsed time: 17 	 Geodes found: 0
# Branches: 283	 Elapsed time: 18 	 Geodes found: 0
# Branches: 461	 Elapsed time: 19 	 Geodes found: 0
# Branches: 780	 Elapsed time: 20 	 Geodes found: 0
# Branches: 1265	 Elapsed time: 21 	 Geodes found: 0
# Branches: 2104	 Elapsed time: 22 	 Geodes found: 0
# Branches: 3739	 Elapsed time: 23 	 Geodes found: 1
# Branches: 6922	 Elapsed time: 24 	 Geodes found: 2
# STARTING on blueprint 20
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 3	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 5	 Elapsed time: 6 	 Geodes found: 0
# Branches: 7	 Elapsed time: 7 	 Geodes found: 0
# Branches: 10	 Elapsed time: 8 	 Geodes found: 0
# Branches: 16	 Elapsed time: 9 	 Geodes found: 0
# Branches: 21	 Elapsed time: 10 	 Geodes found: 0
# Branches: 28	 Elapsed time: 11 	 Geodes found: 0
# Branches: 53	 Elapsed time: 12 	 Geodes found: 0
# Branches: 80	 Elapsed time: 13 	 Geodes found: 0
# Branches: 120	 Elapsed time: 14 	 Geodes found: 0
# Branches: 188	 Elapsed time: 15 	 Geodes found: 0
# Branches: 287	 Elapsed time: 16 	 Geodes found: 0
# Branches: 460	 Elapsed time: 17 	 Geodes found: 0
# Branches: 810	 Elapsed time: 18 	 Geodes found: 0
# Branches: 1451	 Elapsed time: 19 	 Geodes found: 1
# Branches: 2648	 Elapsed time: 20 	 Geodes found: 2
# Branches: 5103	 Elapsed time: 21 	 Geodes found: 4
# Branches: 10165	 Elapsed time: 22 	 Geodes found: 6
# Branches: 20140	 Elapsed time: 23 	 Geodes found: 9
# Branches: 39258	 Elapsed time: 24 	 Geodes found: 12
# STARTING on blueprint 21
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 3	 Elapsed time: 4 	 Geodes found: 0
# Branches: 5	 Elapsed time: 5 	 Geodes found: 0
# Branches: 8	 Elapsed time: 6 	 Geodes found: 0
# Branches: 11	 Elapsed time: 7 	 Geodes found: 0
# Branches: 15	 Elapsed time: 8 	 Geodes found: 0
# Branches: 18	 Elapsed time: 9 	 Geodes found: 0
# Branches: 21	 Elapsed time: 10 	 Geodes found: 0
# Branches: 25	 Elapsed time: 11 	 Geodes found: 0
# Branches: 31	 Elapsed time: 12 	 Geodes found: 0
# Branches: 42	 Elapsed time: 13 	 Geodes found: 0
# Branches: 61	 Elapsed time: 14 	 Geodes found: 0
# Branches: 81	 Elapsed time: 15 	 Geodes found: 0
# Branches: 110	 Elapsed time: 16 	 Geodes found: 0
# Branches: 164	 Elapsed time: 17 	 Geodes found: 0
# Branches: 244	 Elapsed time: 18 	 Geodes found: 0
# Branches: 357	 Elapsed time: 19 	 Geodes found: 0
# Branches: 554	 Elapsed time: 20 	 Geodes found: 0
# Branches: 841	 Elapsed time: 21 	 Geodes found: 0
# Branches: 1215	 Elapsed time: 22 	 Geodes found: 1
# Branches: 1959	 Elapsed time: 23 	 Geodes found: 2
# Branches: 3219	 Elapsed time: 24 	 Geodes found: 3
# STARTING on blueprint 22
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 7	 Elapsed time: 8 	 Geodes found: 0
# Branches: 10	 Elapsed time: 9 	 Geodes found: 0
# Branches: 15	 Elapsed time: 10 	 Geodes found: 0
# Branches: 23	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 43	 Elapsed time: 13 	 Geodes found: 0
# Branches: 57	 Elapsed time: 14 	 Geodes found: 0
# Branches: 78	 Elapsed time: 15 	 Geodes found: 0
# Branches: 114	 Elapsed time: 16 	 Geodes found: 0
# Branches: 162	 Elapsed time: 17 	 Geodes found: 0
# Branches: 241	 Elapsed time: 18 	 Geodes found: 0
# Branches: 380	 Elapsed time: 19 	 Geodes found: 0
# Branches: 613	 Elapsed time: 20 	 Geodes found: 0
# Branches: 1017	 Elapsed time: 21 	 Geodes found: 0
# Branches: 1704	 Elapsed time: 22 	 Geodes found: 0
# Branches: 2741	 Elapsed time: 23 	 Geodes found: 0
# Branches: 4703	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 23
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 4	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 9	 Elapsed time: 8 	 Geodes found: 0
# Branches: 14	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 24	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 38	 Elapsed time: 13 	 Geodes found: 0
# Branches: 44	 Elapsed time: 14 	 Geodes found: 0
# Branches: 48	 Elapsed time: 15 	 Geodes found: 0
# Branches: 73	 Elapsed time: 16 	 Geodes found: 0
# Branches: 98	 Elapsed time: 17 	 Geodes found: 0
# Branches: 115	 Elapsed time: 18 	 Geodes found: 0
# Branches: 153	 Elapsed time: 19 	 Geodes found: 0
# Branches: 211	 Elapsed time: 20 	 Geodes found: 0
# Branches: 293	 Elapsed time: 21 	 Geodes found: 0
# Branches: 431	 Elapsed time: 22 	 Geodes found: 0
# Branches: 651	 Elapsed time: 23 	 Geodes found: 0
# Branches: 988	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 24
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 3	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 5	 Elapsed time: 6 	 Geodes found: 0
# Branches: 7	 Elapsed time: 7 	 Geodes found: 0
# Branches: 10	 Elapsed time: 8 	 Geodes found: 0
# Branches: 16	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 25	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 36	 Elapsed time: 13 	 Geodes found: 0
# Branches: 49	 Elapsed time: 14 	 Geodes found: 0
# Branches: 73	 Elapsed time: 15 	 Geodes found: 0
# Branches: 90	 Elapsed time: 16 	 Geodes found: 0
# Branches: 123	 Elapsed time: 17 	 Geodes found: 0
# Branches: 175	 Elapsed time: 18 	 Geodes found: 0
# Branches: 240	 Elapsed time: 19 	 Geodes found: 0
# Branches: 364	 Elapsed time: 20 	 Geodes found: 0
# Branches: 572	 Elapsed time: 21 	 Geodes found: 0
# Branches: 818	 Elapsed time: 22 	 Geodes found: 0
# Branches: 1343	 Elapsed time: 23 	 Geodes found: 1
# Branches: 2397	 Elapsed time: 24 	 Geodes found: 2
# STARTING on blueprint 25
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 1	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 3	 Elapsed time: 7 	 Geodes found: 0
# Branches: 5	 Elapsed time: 8 	 Geodes found: 0
# Branches: 7	 Elapsed time: 9 	 Geodes found: 0
# Branches: 11	 Elapsed time: 10 	 Geodes found: 0
# Branches: 14	 Elapsed time: 11 	 Geodes found: 0
# Branches: 24	 Elapsed time: 12 	 Geodes found: 0
# Branches: 29	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 46	 Elapsed time: 15 	 Geodes found: 0
# Branches: 63	 Elapsed time: 16 	 Geodes found: 0
# Branches: 97	 Elapsed time: 17 	 Geodes found: 0
# Branches: 126	 Elapsed time: 18 	 Geodes found: 0
# Branches: 164	 Elapsed time: 19 	 Geodes found: 0
# Branches: 244	 Elapsed time: 20 	 Geodes found: 0
# Branches: 356	 Elapsed time: 21 	 Geodes found: 0
# Branches: 541	 Elapsed time: 22 	 Geodes found: 0
# Branches: 839	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1222	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 26
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 5	 Elapsed time: 7 	 Geodes found: 0
# Branches: 7	 Elapsed time: 8 	 Geodes found: 0
# Branches: 10	 Elapsed time: 9 	 Geodes found: 0
# Branches: 15	 Elapsed time: 10 	 Geodes found: 0
# Branches: 23	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 44	 Elapsed time: 13 	 Geodes found: 0
# Branches: 59	 Elapsed time: 14 	 Geodes found: 0
# Branches: 87	 Elapsed time: 15 	 Geodes found: 0
# Branches: 129	 Elapsed time: 16 	 Geodes found: 0
# Branches: 185	 Elapsed time: 17 	 Geodes found: 0
# Branches: 289	 Elapsed time: 18 	 Geodes found: 0
# Branches: 470	 Elapsed time: 19 	 Geodes found: 0
# Branches: 773	 Elapsed time: 20 	 Geodes found: 0
# Branches: 1286	 Elapsed time: 21 	 Geodes found: 0
# Branches: 2067	 Elapsed time: 22 	 Geodes found: 0
# Branches: 3350	 Elapsed time: 23 	 Geodes found: 0
# Branches: 5822	 Elapsed time: 24 	 Geodes found: 1
# STARTING on blueprint 27
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 1	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 3	 Elapsed time: 7 	 Geodes found: 0
# Branches: 5	 Elapsed time: 8 	 Geodes found: 0
# Branches: 7	 Elapsed time: 9 	 Geodes found: 0
# Branches: 11	 Elapsed time: 10 	 Geodes found: 0
# Branches: 14	 Elapsed time: 11 	 Geodes found: 0
# Branches: 24	 Elapsed time: 12 	 Geodes found: 0
# Branches: 29	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 45	 Elapsed time: 15 	 Geodes found: 0
# Branches: 57	 Elapsed time: 16 	 Geodes found: 0
# Branches: 71	 Elapsed time: 17 	 Geodes found: 0
# Branches: 107	 Elapsed time: 18 	 Geodes found: 0
# Branches: 136	 Elapsed time: 19 	 Geodes found: 0
# Branches: 187	 Elapsed time: 20 	 Geodes found: 0
# Branches: 253	 Elapsed time: 21 	 Geodes found: 0
# Branches: 391	 Elapsed time: 22 	 Geodes found: 0
# Branches: 594	 Elapsed time: 23 	 Geodes found: 0
# Branches: 934	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 28
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 1	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 3	 Elapsed time: 7 	 Geodes found: 0
# Branches: 5	 Elapsed time: 8 	 Geodes found: 0
# Branches: 7	 Elapsed time: 9 	 Geodes found: 0
# Branches: 11	 Elapsed time: 10 	 Geodes found: 0
# Branches: 14	 Elapsed time: 11 	 Geodes found: 0
# Branches: 24	 Elapsed time: 12 	 Geodes found: 0
# Branches: 32	 Elapsed time: 13 	 Geodes found: 0
# Branches: 49	 Elapsed time: 14 	 Geodes found: 0
# Branches: 70	 Elapsed time: 15 	 Geodes found: 0
# Branches: 114	 Elapsed time: 16 	 Geodes found: 0
# Branches: 166	 Elapsed time: 17 	 Geodes found: 0
# Branches: 290	 Elapsed time: 18 	 Geodes found: 0
# Branches: 458	 Elapsed time: 19 	 Geodes found: 0
# Branches: 802	 Elapsed time: 20 	 Geodes found: 0
# Branches: 1135	 Elapsed time: 21 	 Geodes found: 0
# Branches: 1821	 Elapsed time: 22 	 Geodes found: 0
# Branches: 2559	 Elapsed time: 23 	 Geodes found: 0
# Branches: 4135	 Elapsed time: 24 	 Geodes found: 1
# STARTING on blueprint 29
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 1	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 3	 Elapsed time: 7 	 Geodes found: 0
# Branches: 5	 Elapsed time: 8 	 Geodes found: 0
# Branches: 7	 Elapsed time: 9 	 Geodes found: 0
# Branches: 11	 Elapsed time: 10 	 Geodes found: 0
# Branches: 14	 Elapsed time: 11 	 Geodes found: 0
# Branches: 24	 Elapsed time: 12 	 Geodes found: 0
# Branches: 29	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 45	 Elapsed time: 15 	 Geodes found: 0
# Branches: 62	 Elapsed time: 16 	 Geodes found: 0
# Branches: 90	 Elapsed time: 17 	 Geodes found: 0
# Branches: 123	 Elapsed time: 18 	 Geodes found: 0
# Branches: 154	 Elapsed time: 19 	 Geodes found: 0
# Branches: 245	 Elapsed time: 20 	 Geodes found: 0
# Branches: 341	 Elapsed time: 21 	 Geodes found: 0
# Branches: 536	 Elapsed time: 22 	 Geodes found: 0
# Branches: 807	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1264	 Elapsed time: 24 	 Geodes found: 0
# STARTING on blueprint 30
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 1	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 3	 Elapsed time: 6 	 Geodes found: 0
# Branches: 3	 Elapsed time: 7 	 Geodes found: 0
# Branches: 5	 Elapsed time: 8 	 Geodes found: 0
# Branches: 7	 Elapsed time: 9 	 Geodes found: 0
# Branches: 11	 Elapsed time: 10 	 Geodes found: 0
# Branches: 14	 Elapsed time: 11 	 Geodes found: 0
# Branches: 24	 Elapsed time: 12 	 Geodes found: 0
# Branches: 30	 Elapsed time: 13 	 Geodes found: 0
# Branches: 42	 Elapsed time: 14 	 Geodes found: 0
# Branches: 59	 Elapsed time: 15 	 Geodes found: 0
# Branches: 98	 Elapsed time: 16 	 Geodes found: 0
# Branches: 121	 Elapsed time: 17 	 Geodes found: 0
# Branches: 202	 Elapsed time: 18 	 Geodes found: 0
# Branches: 300	 Elapsed time: 19 	 Geodes found: 0
# Branches: 526	 Elapsed time: 20 	 Geodes found: 0
# Branches: 791	 Elapsed time: 21 	 Geodes found: 0
# Branches: 1316	 Elapsed time: 22 	 Geodes found: 0
# Branches: 2075	 Elapsed time: 23 	 Geodes found: 0
# Branches: 3541	 Elapsed time: 24 	 Geodes found: 0
# AND THE ENTRY SHOULD BE (FINGERS CROSSED) 790

# %%
second_entry = 1
for line in range(3):
    b = Blueprint(*process_line(contents[line]), STARTING_STATE)
    print("STARTING on blueprint {}".format(b.id))
    
    for i in range(32):
        b.add_a_minute()
        print('Branches: {}\t Elapsed time: {} \t Geodes found: {}'.format(len(b.minute_lists[-1]),b.elapsed_time(),b.geodes(b.elapsed_time())) )   
    
    second_entry = entry *b.geodes(32)

print("AND THE ENTRY SHOULD BE (FINGERS CROSSED) {}".format(second_entry))
# Out:
# STARTING on blueprint 1
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 2	 Elapsed time: 3 	 Geodes found: 0
# Branches: 2	 Elapsed time: 4 	 Geodes found: 0
# Branches: 4	 Elapsed time: 5 	 Geodes found: 0
# Branches: 6	 Elapsed time: 6 	 Geodes found: 0
# Branches: 10	 Elapsed time: 7 	 Geodes found: 0
# Branches: 14	 Elapsed time: 8 	 Geodes found: 0
# Branches: 19	 Elapsed time: 9 	 Geodes found: 0
# Branches: 23	 Elapsed time: 10 	 Geodes found: 0
# Branches: 28	 Elapsed time: 11 	 Geodes found: 0
# Branches: 31	 Elapsed time: 12 	 Geodes found: 0
# Branches: 34	 Elapsed time: 13 	 Geodes found: 0
# Branches: 39	 Elapsed time: 14 	 Geodes found: 0
# Branches: 49	 Elapsed time: 15 	 Geodes found: 0
# Branches: 64	 Elapsed time: 16 	 Geodes found: 0
# Branches: 86	 Elapsed time: 17 	 Geodes found: 0
# Branches: 104	 Elapsed time: 18 	 Geodes found: 0
# Branches: 145	 Elapsed time: 19 	 Geodes found: 0
# Branches: 211	 Elapsed time: 20 	 Geodes found: 0
# Branches: 327	 Elapsed time: 21 	 Geodes found: 0
# Branches: 471	 Elapsed time: 22 	 Geodes found: 0
# Branches: 783	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1235	 Elapsed time: 24 	 Geodes found: 1
# Branches: 2089	 Elapsed time: 25 	 Geodes found: 2
# Branches: 3725	 Elapsed time: 26 	 Geodes found: 3
# Branches: 6704	 Elapsed time: 27 	 Geodes found: 5
# Branches: 12555	 Elapsed time: 28 	 Geodes found: 7
# Branches: 24351	 Elapsed time: 29 	 Geodes found: 10
# Branches: 45791	 Elapsed time: 30 	 Geodes found: 13
# Branches: 86327	 Elapsed time: 31 	 Geodes found: 17
# Branches: 156437	 Elapsed time: 32 	 Geodes found: 21
# STARTING on blueprint 2
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 3	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 5	 Elapsed time: 6 	 Geodes found: 0
# Branches: 7	 Elapsed time: 7 	 Geodes found: 0
# Branches: 10	 Elapsed time: 8 	 Geodes found: 0
# Branches: 16	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 25	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 36	 Elapsed time: 13 	 Geodes found: 0
# Branches: 42	 Elapsed time: 14 	 Geodes found: 0
# Branches: 62	 Elapsed time: 15 	 Geodes found: 0
# Branches: 84	 Elapsed time: 16 	 Geodes found: 0
# Branches: 93	 Elapsed time: 17 	 Geodes found: 0
# Branches: 134	 Elapsed time: 18 	 Geodes found: 0
# Branches: 185	 Elapsed time: 19 	 Geodes found: 0
# Branches: 265	 Elapsed time: 20 	 Geodes found: 0
# Branches: 378	 Elapsed time: 21 	 Geodes found: 0
# Branches: 556	 Elapsed time: 22 	 Geodes found: 0
# Branches: 812	 Elapsed time: 23 	 Geodes found: 0
# Branches: 1138	 Elapsed time: 24 	 Geodes found: 0
# Branches: 1644	 Elapsed time: 25 	 Geodes found: 0
# Branches: 2602	 Elapsed time: 26 	 Geodes found: 1
# Branches: 4236	 Elapsed time: 27 	 Geodes found: 2
# Branches: 6960	 Elapsed time: 28 	 Geodes found: 3
# Branches: 11409	 Elapsed time: 29 	 Geodes found: 4
# Branches: 19191	 Elapsed time: 30 	 Geodes found: 6
# Branches: 33220	 Elapsed time: 31 	 Geodes found: 8
# Branches: 56299	 Elapsed time: 32 	 Geodes found: 10
# STARTING on blueprint 3
# Branches: 1	 Elapsed time: 1 	 Geodes found: 0
# Branches: 1	 Elapsed time: 2 	 Geodes found: 0
# Branches: 1	 Elapsed time: 3 	 Geodes found: 0
# Branches: 3	 Elapsed time: 4 	 Geodes found: 0
# Branches: 3	 Elapsed time: 5 	 Geodes found: 0
# Branches: 5	 Elapsed time: 6 	 Geodes found: 0
# Branches: 7	 Elapsed time: 7 	 Geodes found: 0
# Branches: 10	 Elapsed time: 8 	 Geodes found: 0
# Branches: 16	 Elapsed time: 9 	 Geodes found: 0
# Branches: 20	 Elapsed time: 10 	 Geodes found: 0
# Branches: 25	 Elapsed time: 11 	 Geodes found: 0
# Branches: 32	 Elapsed time: 12 	 Geodes found: 0
# Branches: 36	 Elapsed time: 13 	 Geodes found: 0
# Branches: 52	 Elapsed time: 14 	 Geodes found: 0
# Branches: 74	 Elapsed time: 15 	 Geodes found: 0
# Branches: 93	 Elapsed time: 16 	 Geodes found: 0
# Branches: 125	 Elapsed time: 17 	 Geodes found: 0
# Branches: 178	 Elapsed time: 18 	 Geodes found: 0
# Branches: 256	 Elapsed time: 19 	 Geodes found: 0
# Branches: 379	 Elapsed time: 20 	 Geodes found: 0
# Branches: 617	 Elapsed time: 21 	 Geodes found: 0
# Branches: 999	 Elapsed time: 22 	 Geodes found: 1
# Branches: 1769	 Elapsed time: 23 	 Geodes found: 2
# Branches: 3423	 Elapsed time: 24 	 Geodes found: 3
# Branches: 6318	 Elapsed time: 25 	 Geodes found: 5
# Branches: 12841	 Elapsed time: 26 	 Geodes found: 7
# Branches: 25829	 Elapsed time: 27 	 Geodes found: 10
# Branches: 48326	 Elapsed time: 28 	 Geodes found: 14
# Branches: 91982	 Elapsed time: 29 	 Geodes found: 18
# Branches: 170465	 Elapsed time: 30 	 Geodes found: 23
# Branches: 295351	 Elapsed time: 31 	 Geodes found: 29
# Branches: 511130	 Elapsed time: 32 	 Geodes found: 35
# AND THE ENTRY SHOULD BE (FINGERS CROSSED) 790

# %%
21*10*35
# Out:
# 7350
